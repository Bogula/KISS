# %% [markdown]
# <a href="https://colab.research.google.com/github/Bogula/KISS/blob/main/Spachausgabe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Library ist nicht in Colab eingebaut
#Muss extra installiert werden.
#Jedoch nur einmal, danach kann man im
#Notebook auf die Funktion zugreifen 

# !pip install gtts

# %%
# Import der module for text 
# to speech conversion und Ausgabe

import IPython
from gtts import gTTS
  
import os

# %%
  
# Text, den man ausgeben will
#mytext = 'Welcome to Artificial Intelligence Center Hamburg!'
  
mytext = "Hallo wie geht es euch heute abend? Ich hoffe, der Kurs hat euch ein wenig Spaß gemacht."

# Sprache
language = 'de'
  
# Slow oder fast

myobj = gTTS(text=mytext, lang=language, slow=False)
  

# in Datei schreiben mp3
myobj.save("sagwas.mp3")

#Datei ausgeben
IPython.display.Audio('sagwas.mp3', autoplay=True)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
